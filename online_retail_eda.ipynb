# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# loading datasets in DataFrame
df = pd.read_csv("online_retail.csv")

# %%
# printing datasets
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Data Inspection

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID Country
# 541904  2011-12-09 12:50:00       0.85     12680.0  France
# 541905  2011-12-09 12:50:00       2.10     12680.0  France
# 541906  2011-12-09 12:50:00       4.15     12680.0  France
# 541907  2011-12-09 12:50:00       4.15     12680.0  France
# 541908  2011-12-09 12:50:00       4.95     12680.0  France

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.shape
# Out:
# (541909, 8)

# %%
# Data Cleaning- nulls, duplicates.

df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# fill description
df['Description'] = df['Description'].fillna('Unknown')

df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# fill customer id
df['CustomerID'] = df['CustomerID'].fillna(0)

df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Type Casting : Convert InvoiceDate to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# Type Casting : Convert CustomerID to integer
df['CustomerID'] = df['CustomerID'].astype(int)

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int64
# Country                object
# dtype: object

# %%
# Remove negative quantity
df = df[df['Quantity'] > 0]

# %%
# Remove negative price
df = df[df['UnitPrice'] > 0]

# %%
# Create Total Sales column
df['Sales'] = df['Quantity'] * df['UnitPrice']

# %%
# Feature Engineering
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['MonthName'] = df['InvoiceDate'].dt.month_name()
df['Day'] = df['InvoiceDate'].dt.day_name()
df['Hour'] = df['InvoiceDate'].dt.hour

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 530104 entries, 0 to 541908
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    530104 non-null  object
#  1   StockCode    530104 non-null  object
#  2   Description  530104 non-null  object
#  3   Quantity     530104 non-null  int64
#  4   InvoiceDate  530104 non-null  datetime64[ns]
#  5   UnitPrice    530104 non-null  float64
#  6   CustomerID   530104 non-null  int64
#  7   Country      530104 non-null  object
#  8   Sales        530104 non-null  float64
#  9   Year         530104 non-null  int32
#  10  Month        530104 non-null  int32
#  11  MonthName    530104 non-null  object
#  12  Day          530104 non-null  object
#  13  Hour         530104 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(3), int64(2), object(6)
# memory usage: 54.6+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Sales  Year  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom  15.30  2010
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom  20.34  2010
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom  22.00  2010
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom  20.34  2010
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom  20.34  2010
#
#    Month MonthName        Day  Hour
# 0     12  December  Wednesday     8
# ...

# %%
# cheking duplicates
df.duplicated().sum()
# Out:
# np.int64(5226)

# %%
# Displaying duplicate rows
duplicates = df[df.duplicated()]

duplicates.head()
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 517    536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527    536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537    536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539    536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555    536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Sales  Year  \
# 517 2010-12-01 11:45:00       1.25       17908  United Kingdom   1.25  2010
# 527 2010-12-01 11:45:00       2.10       17908  United Kingdom   2.10  2010
# 537 2010-12-01 11:45:00       2.95       17908  United Kingdom   2.95  2010
# 539 2010-12-01 11:45:00       4.95       17908  United Kingdom   4.95  2010
# 555 2010-12-01 11:49:00       2.95       17920  United Kingdom   2.95  2010
#
#      Month MonthName        Day  Hour
# 517     12  December  Wednesday    11
# ...

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (524878, 14)

# %%
# checking outliers using boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Sales'])
plt.title('Boxplot of Sales')
plt.show()



plt.figure(figsize=(10, 6))
sns.boxplot(x=df['UnitPrice'])
plt.title('Boxplot of Unit Price')
plt.show()


plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Quantity'])
plt.title('Boxplot of Quantity')
plt.show()

plt.tight_layout()
plt.show()

# %%
# Detect Outliers Using IQR Method

Q1 = df['Quantity'].quantile(0.25)
Q3 = df['Quantity'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['Quantity'] < lower) | (df['Quantity'] > upper)]

print(outliers)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 9         536367     84879     ASSORTED COLOUR BIRD ORNAMENT        32
# 31        536370     10002       INFLATABLE POLITICAL GLOBE         48
# 44        536370     22492           MINI PAINT SET VINTAGE         36
# 46        536371     22086   PAPER CHAIN KIT 50'S CHRISTMAS         80
# 65        536374     21258        VICTORIAN SEWING BOX LARGE        32
# ...          ...       ...                               ...       ...
# 541835    581579     23581            JUMBO BAG PAISLEY PARK        40
# 541865    581583     20725           LUNCH BAG RED RETROSPOT        40
# 541866    581583     85038   6 CHOCOLATE LOVE HEART T-LIGHTS        36
# 541867    581584     20832  RED FLOCK LOVE HEART PHOTO FRAME        72
# 541868    581584     85038   6 CHOCOLATE LOVE HEART T-LIGHTS        48
#
#                InvoiceDate  UnitPrice  CustomerID         Country   Sales  \
# ...

# %%
# count of outliers
outliers_count = outliers.shape[0]
print("Number of outliers:", outliers_count)
# Out:
# Number of outliers: 27111

# %%
# Detect Outliers Using IQR Method for all three numeric columns

for col in ['Quantity','UnitPrice','Sales']:
    
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    
    print(col, "Outliers:", outliers.shape[0])
# Out:
# Quantity Outliers: 27111
# UnitPrice Outliers: 37827
# Sales Outliers: 42624

# %%
df = pd.read_csv(
    "online_retail.csv",
    dtype={'InvoiceNo': str},
    low_memory=False
)

# Save new clean CSV
df.to_csv("online_retail_final.csv", index=False)

# %% [markdown]
# # Questions : For Projects

# %%
#1. What is the shape of the dataset? 

df.shape
# Out:
# (541909, 8)

# %%
# 2. What are the column names in the dataset?
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#3. What are the data types of each column?
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
#4. How many missing values are present in each column?
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#5. How many duplicate rows exist in the dataset? 
df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
# 6. What is the distribution of numerical features? *(Histogram)*
df.hist(figsize=(15,15))
plt.tight_layout()
plt.show()

# %%
# 7. What is the distribution of Quantity sold? *
plt.hist(df['Quantity'], bins=20)
plt.title('Quantity Distribution')
plt.show()

# %%
# 8. What is the distribution of UnitPrice?
plt.hist(df["UnitPrice"],bins = 20)
plt.title("Distribution of unit price")
plt.show()

# %%
# 9. Are there outliers in Quantity? 
sns.boxplot(x=df["Quantity"])
plt.show()

# %%
# 10. Are there outliers in UnitPrice? 
sns.boxplot(x=df["UnitPrice"])
plt.show()

# %%
# 11. How many unique customers are there? *(KPI/Card)*
df["CustomerID"].nunique()
# Out:
# 4372

# %%
# 12. How many unique products are available? 
df["Description"].nunique()
# Out:
# 4223

# %%
# 13. What is the total revenue generated?
df['Sales'] = df['Quantity'] * df['UnitPrice']
df['Sales'].sum()
# Out:
# np.float64(9747747.934)

# %%
# 14. Which country generated the highest revenue? 
country_sales = df.groupby("Country")["Sales"].sum().sort_values(ascending = False).head(10)
country_sales.plot(kind="bar")
plt.show()

# %%
# 15. Which country placed the highest number of orders?
orders = df.groupby("Country")["InvoiceNo"].nunique().sort_values(ascending=False).head(10)
orders.plot(kind="bar")
plt.show()

# %%
# 16. Which countries contribute most to overall revenue? 

country_share = df.groupby('Country')['Sales'].sum().sort_values(ascending=False).head(5)
country_share.plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.show()

# %%
# 17. What are the top 10 products by quantity sold? 
top_products = df.groupby("Description")["Quantity"].sum().sort_values(ascending=False).head(10)
top_products.plot(kind="barh")
plt.show()

# %%
# 18. What are the top 10 products by revenue generated?
top_product_by_revenue = df.groupby("Description")["Sales"].sum().sort_values(ascending=False).head(10)
top_product_by_revenue.plot(kind="barh")
plt.show()

# %%
# 19. What are the least selling products? 
least_products = df.groupby('Description')['Quantity'].sum().sort_values().head(10)
least_products.plot(kind='barh')
plt.show()

# %%
# 20. Which stock codes are sold the most?
stock = df.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False).head(10)
stock.plot(kind='bar')
plt.show()

# %%
# 21. Which products have the highest average price?
avg_price = df.groupby('Description')['UnitPrice'].mean().sort_values(ascending=False).head(10)
avg_price.plot(kind='bar')
plt.show()

# %%
# 22. What products generate the highest average revenue?
avg_revenue = df.groupby('Description')['Sales'].mean().sort_values(ascending=False).head(10)
avg_revenue.plot(kind='bar')
plt.show()

# %%
# Feature Engineering
# Convert InvoiceDate to datetime format
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Feature Engineering
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['MonthName'] = df['InvoiceDate'].dt.month_name()
df['Day'] = df['InvoiceDate'].dt.day
df['Hour'] = df['InvoiceDate'].dt.hour

# Check output
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Sales  Year  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30  2010
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34  2010
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00  2010
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34  2010
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34  2010
#
#    Month MonthName  Day  Hour
# 0     12  December    1     8
# 1     12  December    1     8
# ...

# %%
# 23. What was the best month for sales?
monthly_sales = df.groupby('Month')['Sales'].sum().sort_values(ascending=False)
print(monthly_sales.head(1))
# Out:
# Month
# 11    1461756.25
# Name: Sales, dtype: float64

# %%
# 24. How much revenue was earned in the best month? 
monthly_sales.plot(kind='bar')
plt.show()

# %%
# 25. Which month had the lowest sales?
print(monthly_sales.tail(1))
# Out:
# Month
# 4    493207.121
# Name: Sales, dtype: float64

# %%
# 26. What is the monthly sales trend? 
monthly_trend = df.groupby('Month')['Sales'].sum()
monthly_trend.plot(marker='o')
plt.show()

# %%
# 27. What is the yearly sales trend?
yearly_sales = df.groupby('Year')['Sales'].sum()
yearly_sales.plot(kind='bar')
plt.show()

# %%
# 28. What is the cumulative revenue trend over time?
cumulative = df.groupby('Month')['Sales'].sum().cumsum()
cumulative.plot()
plt.show()

# %%
# 29. What is the moving average sales trend?
moving = df.groupby('Month')['Sales'].sum().rolling(2).mean()
moving.plot()
plt.show()

# %%
# 30. Which day of the week has the highest sales? 
weekday_sales = df.groupby('Day')['Sales'].sum()
weekday_sales.plot(kind='bar')
plt.show()

# %%
# 31. Which weekdays are busiest for shopping?
weekday_orders = df.groupby('Day')['InvoiceNo'].count()
weekday_orders.plot(kind='bar')
plt.show()

# %%
# 32. Which hour of the day has the highest sales? 
hour_sales = df.groupby('Hour')['Sales'].sum()
hour_sales.plot(marker='o')
plt.show()

# %%
# 33. What are the busiest shopping hours?
hour_orders = df.groupby('Hour')['InvoiceNo'].count()
hour_orders.plot(marker='o')
plt.show()

# %%
# 34. What time should advertisements be displayed to maximize sales?
peak_hours = df.groupby('Hour')['InvoiceNo'].count()
print(peak_hours.sort_values(ascending=False).head())
# Out:
# Hour
# 12    78709
# 15    77519
# 13    72259
# 14    67471
# 11    57674
# Name: InvoiceNo, dtype: int64

# %%
# 35. Which invoices generated the highest revenue?
invoice_sales = df.groupby('InvoiceNo')['Sales'].sum().sort_values(ascending=False).head(10)
invoice_sales.plot(kind='bar')
plt.show()

# %%
# 36. What is the average order value?
avg_order = df.groupby('InvoiceNo')['Sales'].sum().mean()
print(avg_order)
# Out:
# 376.3609240926641

# %%
# 37. How many products are sold per invoice on average? 
products_invoice = df.groupby('InvoiceNo')['Description'].count()
plt.hist(products_invoice, bins=30)
plt.show()

# %%
# 38. Which invoices contain the largest quantity of products? 
invoice_qty = df.groupby('InvoiceNo')['Quantity'].sum().sort_values(ascending=False).head(10)
invoice_qty.plot(kind='bar')
plt.show()

# %%
# 39. What products are most often sold together?
basket = df.groupby('InvoiceNo')['Description'].apply(lambda x: ', '.join(x.astype(str)))
print(basket.head())
# Out:
# InvoiceNo
# 536365    WHITE HANGING HEART T-LIGHT HOLDER, WHITE META...
# 536366    HAND WARMER UNION JACK, HAND WARMER RED POLKA DOT
# 536367    ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHOU...
# 536368    JAM MAKING SET WITH JARS, RED COAT RACK PARIS ...
# 536369                             BATH BUILDING BLOCK WORD
# Name: Description, dtype: object

# %%
# 40. What is the correlation between Quantity, UnitPrice, and Sales? 
corr = df[['Quantity','UnitPrice','Sales']].corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
# 41. Who are the top 10 customers by revenue? 
top_customers = df.groupby('CustomerID')['Sales'].sum().sort_values(ascending=False).head(10)
top_customers.plot(kind='bar')
plt.show()

# %%
# 42. Who are the most frequent buyers?
freq_buyers = df.groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False).head(10)
print(freq_buyers)
# Out:
# CustomerID
# 14911.0    248
# 12748.0    224
# 17841.0    169
# 14606.0    128
# 15311.0    118
# 13089.0    118
# 12971.0     89
# 14527.0     86
# 13408.0     81
# 14646.0     77
# Name: InvoiceNo, dtype: int64

# %%
# 43. What percentage of revenue comes from top customers? 
customer_sales = df.groupby('CustomerID')['Sales'].sum().sort_values(ascending=False)
top20 = customer_sales.head(int(len(customer_sales)*0.2)).sum()
percentage = (top20/customer_sales.sum())*100
print(percentage)
# Out:
# 73.82295006221261

# %%
# 44. How many one-time customers exist?
one_time = df.groupby('CustomerID')['InvoiceNo'].nunique()
one_time = one_time[one_time == 1]
print(len(one_time))
# Out:
# 1313

# %%
# 45. What is the customer retention behavior? 
retention = df.groupby('CustomerID')['InvoiceNo'].nunique()
retention.plot(kind='hist')
plt.show()

# %%
# 46. What does the RFM analysis reveal about customers? 
snapshot = df['InvoiceDate'].max()

rfm = df.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (snapshot - x.max()).days,
    'InvoiceNo': 'nunique',
    'Sales': 'sum'
})

# %%
rfm.columns = ['Recency','Frequency','Monetary']
print(rfm.head())
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         325          2      0.00
# 12347.0           1          7   4310.00
# 12348.0          74          4   1797.24
# 12349.0          18          1   1757.55
# 12350.0         309          1    334.40

# %%
# 47. Which products have high demand but low price?
high_demand = df.groupby('Description').agg({'Quantity':'sum','UnitPrice':'mean'})
high_demand.sort_values(['Quantity','UnitPrice'], ascending=[False,True]).head(10)
# Out:
#                                     Quantity  UnitPrice
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS      53847   0.319908
# JUMBO BAG RED RETROSPOT                47363   2.470264
# ASSORTED COLOUR BIRD ORNAMENT          36381   1.722032
# POPCORN HOLDER                         36334   1.010983
# PACK OF 72 RETROSPOT CAKE CASES        36039   0.755986
# WHITE HANGING HEART T-LIGHT HOLDER     35317   3.204251
# RABBIT NIGHT LIGHT                     30680   2.375385
# MINI PAINT SET VINTAGE                 26437   0.781564
# PACK OF 12 LONDON TISSUES              26315   0.446083
# PACK OF 60 PINK PAISLEY CAKE CASES     24753   0.741217

# %%
# 47. Which products have high demand but low price?
high_demand = df.groupby('Description').agg({'Quantity':'sum','UnitPrice':'mean'})
high_demand.sort_values(['Quantity','UnitPrice'], ascending=[False,True]).head(10)
plt.figure(figsize=(10,6))
sns.scatterplot(x='UnitPrice', y='Quantity', data=high_demand)
plt.title('High Demand vs Low Price Products')
plt.show()

# %%
# 48. Which products have low demand but high price? 
low_demand = df.groupby('Description').agg({'Quantity':'sum','UnitPrice':'mean'})
low_demand.sort_values(['Quantity','UnitPrice'], ascending=[True,False]).head(10)
sns.scatterplot(x='UnitPrice', y='Quantity', data=low_demand)
plt.title('Low Demand vs High Price Products')
plt.show()

# %%
# 49. What business insights can be generated from sales trends and customer behavior?


# Business insights
insights = [
    'Sales increase in festive seasons',
    'Afternoon and evening hours have higher sales',
    'Monthly sales trends show seasonal demand',
    'Few products contribute maximum revenue',
    'Customer buying patterns vary by month'
]

# Plot
plt.figure(figsize=(10,5))

plt.barh(insights, [1,1,1,1,1])

plt.title('Business Insights from Sales Trends')
plt.xticks([])

plt.show()

# %%
# 50. What recommendations can improve future sales and customer retention?

# Recommendations
recommendations = [
    'Run ads during peak hours',
    'Provide seasonal discounts',
    'Improve customer retention programs',
    'Promote high-selling products',
    'Bundle related products together'
]

# Plot
plt.figure(figsize=(10,5))

plt.barh(recommendations, [1,1,1,1,1])

plt.title('Recommendations for Future Sales Growth')
plt.xticks([])

plt.show()
